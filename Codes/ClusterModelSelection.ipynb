# %%
import pandas as pd
import numpy as np
import pdb
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
# from scipy.misc import imread
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score
from sklearn.neighbors import KNeighborsRegressor
import tensorflow as tf
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
import lightgbm as gbm
from sklearn.decomposition import PCA
import os
import pickle
# %matplotlib nbagg
from sklearn.cluster import KMeans
# Out:
# C:\Users\Renganathan\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = pd.read_csv('TrainDataScaledPCA.csv', index_col=0)
X = data.drop('default_ind', axis=1)
y = data['default_ind']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

train_data = X_train.copy()
train_data['default_ind'] = y_train

cluster_model = KMeans(n_clusters=2, n_jobs=-1, verbose=100, random_state=7)
cluster_model.fit(X_train)
cluster_y = cluster_model.predict(X_train)

# %%
train_data1 = train_data.iloc[np.where(cluster_y == 0)[0]]
train_data2 = train_data.iloc[np.where(cluster_y == 1)[0]]

# %%
testcluster_y = cluster_model.predict(X_test)

X_test1 = X_test.iloc[np.where(testcluster_y == 0)[0]]
y_test1 = y_test.iloc[np.where(testcluster_y == 0)[0]]

X_test2 = X_test.iloc[np.where(testcluster_y == 1)[0]]
y_test2 = y_test.iloc[np.where(testcluster_y == 1)[0]]

# %%
print('Percent in Cluster 1 =', round(len(train_data1)/len(train_data)*100, 3), '%')
print('Percent in Cluster 2 =', round(len(train_data2)/len(train_data)*100, 3), '%')

print('Percent 1 in Cluster 1', round(sum(train_data1['default_ind']==1)/len(train_data1)*100, 4), '%')
print('Percent 1 in Cluster 2', round(sum(train_data2['default_ind']==1)/len(train_data2)*100, 4), '%')
# Out:
# Percent in Cluster 1 = 19.136 %
# Percent in Cluster 2 = 80.864 %
# Percent 1 in Cluster 1 12.741 %
# Percent 1 in Cluster 2 32.5023 %

# %%
print('Percent in Cluster 1 =', round(len(X_test1)/len(X_test)*100, 3), '%')
print('Percent in Cluster 2 =', round(len(X_test2)/len(X_test)*100, 3), '%')

print('Percent 1 in Cluster 1', round(sum(y_test1==1)/len(y_test1)*100, 4), '%')
print('Percent 1 in Cluster 2', round(sum(y_test2==1)/len(y_test2)*100, 4), '%')
# Out:
# Percent in Cluster 1 = 19.303 %
# Percent in Cluster 2 = 80.697 %
# Percent 1 in Cluster 1 12.1736 %
# Percent 1 in Cluster 2 32.611 %

# %%
def model_selection(train_data, X_test, y_test):
    
    test_results = []

    ns = [50, 150, 350, 500]
    max_depths = [1, 2, 3, 5, 7, 10]
    ts = [0.45, 0.5, 0.55, 0.6]
    bagging_fractions = [0.8, 0.9, 1]

    i = 0

    pos_class = train_data[train_data['default_ind']==1]
    neg_class = train_data[train_data['default_ind']==0]
    print('Fraction of 1 =', len(neg_class)/len(train_data))
    
    try:
        neg_resampled = neg_class.sample(n= int(1 * len(pos_class)), replace=False)
    except:
        print('No Need to Undersample')
        neg_resampled = neg_class
        
    train_data_resampled = pd.concat([pos_class, neg_resampled])

    # Use these for Trainings

    X_train_resampled = train_data_resampled.drop('default_ind', axis=1)
    y_train_resampled = train_data_resampled['default_ind']    

    for n in ns:
        for max_depth in max_depths:

            print('\n\n', round(i/30*100, 3), '% Done')
            i += 1
            print('Number of Estimators =', n, 'Depth =', max_depth)
            
            #Training

            #XGBoost
            model_XGB = XGBClassifier(n_estimators = n , learning_rate=0.1, max_depth=max_depth ,reg_lambda=0.01, n_jobs = -1, verbose =100) 
            model_XGB.fit(X_train_resampled, y_train_resampled)

            y_hat_XGB = model_XGB.predict(X_train_resampled)
            print('\nTrain Balanced Accuracy XGB =', balanced_accuracy_score(y_train_resampled, y_hat_XGB))
            print('Train F1 Score XGB =', f1_score(y_train_resampled, y_hat_XGB))    
            print('Train Precision XGB=', precision_score(y_train_resampled, y_hat_XGB))
            print('Train Recall XGB=', recall_score(y_train_resampled, y_hat_XGB))

            y_test_predXGB = model_XGB.predict(X_test)
            print('\nTest Balanced Score XGB =', balanced_accuracy_score(y_test, y_test_predXGB))
            print('Test F1 Score XGB =', f1_score(y_test, y_test_predXGB)) 
            print('Test Precision XGB=', precision_score(y_test, y_test_predXGB))
            print('Test Recall XGB=', recall_score(y_test, y_test_predXGB))
            
            result = {}
            result['t'] = None
            result['n'] = n
            result['depth'] = max_depth
            result['model'] = 'XGB'
            result['bal_acc'] = balanced_accuracy_score(y_test, y_test_predXGB)
            result['f1'] = f1_score(y_test, y_test_predXGB)
            result['Precision'] = precision_score(y_test, y_test_predXGB)
            result['Recall'] = recall_score(y_test, y_test_predXGB)
            result['Bagging'] = None
            
            test_results.append(result)
            
            for t in ts:
                for bf in bagging_fractions:

                    #LightBoost
                    cv_params = {
                    'max_depth': max_depth,
                    'objective': 'binary',
                    'metric':'auc',  
                    'feature_fraction': 1, 
                    'bagging_fraction': bf,
                    'reg_lambda': 1,
                    'n_estimators': n
                    }

                    print('\nThreshold for LightBoost =', t)
                    gbm_train = gbm.Dataset(X_train_resampled, y_train_resampled)
                    model_LB = gbm.train(cv_params,  
                                gbm_train,
                                verbose_eval=1)

                    y_train_prob = model_LB.predict(X_train_resampled)
                    thres = t
                    y_pred_train = np.zeros(len(y_train_prob))
                    y_pred_train[np.argwhere(y_train_prob>thres)] = 1
                    print('Train Balanced Score LB =', balanced_accuracy_score(y_train_resampled, y_pred_train))
                    print('Train F1 Score LB =', f1_score(y_train_resampled, y_pred_train))
                    print('Train Precision LB=', precision_score(y_train_resampled, y_pred_train))
                    print('Train Recall LB=', recall_score(y_train_resampled, y_pred_train))

                    y_test_prob = model_LB.predict(X_test)    
                    y_pred_test = np.zeros(len(y_test_prob))
                    y_pred_test[np.argwhere(y_test_prob>thres)] = 1    
                    print('\nTest Balanced Score LB=', balanced_accuracy_score(y_test, y_pred_test))
                    print('Test F1 Score LB=', f1_score(y_test, y_pred_test))
                    print('Test Precision LB=', precision_score(y_test, y_pred_test))
                    print('Test Recall LB=', recall_score(y_test, y_pred_test))

                    result = {}
                    result['t'] = thres
                    result['n'] = n
                    result['depth'] = max_depth
                    result['model'] = 'LB'
                    result['bal_acc'] = balanced_accuracy_score(y_test, y_pred_test)
                    result['f1'] = f1_score(y_test, y_pred_test)
                    result['Precision'] = precision_score(y_test, y_pred_test)
                    result['Recall'] = recall_score(y_test, y_pred_test)
                    result['Bagging'] = bf
                    test_results.append(result)
                
    return pd.DataFrame(test_results)

# %% [markdown]
# ### Cluster 1

# %%
results1 = model_selection(train_data1, X_test1, y_test1)
results1.to_csv('Results1_2.csv')
# Out:
# Fraction of 1 = 0.8725902419674733
#
#
#  0.0 % Done
# Number of Estimators = 50 Depth = 1
#
# Train Balanced Accuracy XGB = 0.6699875466998755
# Train F1 Score XGB = 0.6272855133614627
# Train Precision XGB= 0.7205169628432956
# Train Recall XGB= 0.5554171855541719
#
# Test Balanced Score XGB = 0.6515621413710639
# Test F1 Score XGB = 0.33666666666666667
# Test Precision XGB= 0.24846248462484624
# Test Recall XGB= 0.5219638242894057
#
# Threshold for LightBoost = 0.45
# C:\Users\Renganathan\Anaconda3\lib\site-packages\lightgbm\engine.py:113: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Train Balanced Score LB = 0.6855541718555418
# Train F1 Score LB = 0.6821900566393958
# Train Precision LB= 0.6895674300254453
# Train Recall LB= 0.6749688667496887
#
# Test Balanced Score LB= 0.6633450685976174
# Test F1 Score LB= 0.32408575031525855
# Test Precision LB= 0.21434528773978315
# Test Recall LB= 0.6640826873385013
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.6855541718555418
# Train F1 Score LB = 0.6821900566393958
# Train Precision LB= 0.6895674300254453
# Train Recall LB= 0.6749688667496887
#
# Test Balanced Score LB= 0.6633450685976174
# Test F1 Score LB= 0.32408575031525855
# Test Precision LB= 0.21434528773978315
# Test Recall LB= 0.6640826873385013
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.6855541718555418
# Train F1 Score LB = 0.6821900566393958
# Train Precision LB= 0.6895674300254453
# Train Recall LB= 0.6749688667496887
#
# Test Balanced Score LB= 0.6633450685976174
# Test F1 Score LB= 0.32408575031525855
# Test Precision LB= 0.21434528773978315
# Test Recall LB= 0.6640826873385013
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.6706102117061021
# Train F1 Score LB = 0.6272022551092318
# Train Precision LB= 0.7224025974025974
# Train Recall LB= 0.5541718555417185
#
# Test Balanced Score LB= 0.6572289413088707
# Test F1 Score LB= 0.34367141659681477
# Test Precision LB= 0.2543424317617866
# Test Recall LB= 0.5297157622739018
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.6706102117061021
# Train F1 Score LB = 0.6272022551092318
# Train Precision LB= 0.7224025974025974
# Train Recall LB= 0.5541718555417185
#
# Test Balanced Score LB= 0.6572289413088707
# Test F1 Score LB= 0.34367141659681477
# Test Precision LB= 0.2543424317617866
# Test Recall LB= 0.5297157622739018
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.6706102117061021
# Train F1 Score LB = 0.6272022551092318
# Train Precision LB= 0.7224025974025974
# Train Recall LB= 0.5541718555417185
#
# Test Balanced Score LB= 0.6572289413088707
# Test F1 Score LB= 0.34367141659681477
# Test Precision LB= 0.2543424317617866
# Test Recall LB= 0.5297157622739018
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6566002490660026
# Train F1 Score LB = 0.5769083237437668
# Train Precision LB= 0.7512487512487512
# Train Recall LB= 0.46824408468244083
#
# Test Balanced Score LB= 0.6470841385131383
# Test F1 Score LB= 0.3497487437185929
# Test Precision LB= 0.28618421052631576
# Test Recall LB= 0.4496124031007752
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6566002490660026
# Train F1 Score LB = 0.5769083237437668
# Train Precision LB= 0.7512487512487512
# Train Recall LB= 0.46824408468244083
#
# Test Balanced Score LB= 0.6470841385131383
# Test F1 Score LB= 0.3497487437185929
# Test Precision LB= 0.28618421052631576
# Test Recall LB= 0.4496124031007752
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6566002490660026
# Train F1 Score LB = 0.5769083237437668
# Train Precision LB= 0.7512487512487512
# Train Recall LB= 0.46824408468244083
#
# Test Balanced Score LB= 0.6470841385131383
# Test F1 Score LB= 0.3497487437185929
# Test Precision LB= 0.28618421052631576
# Test Recall LB= 0.4496124031007752
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6410336239103362
# Train F1 Score LB = 0.5241436236070985
# Train Precision LB= 0.7772337821297429
# Train Recall LB= 0.3953922789539228
#
# Test Balanced Score LB= 0.6420179841999659
# Test F1 Score LB= 0.3585564610011641
# Test Precision LB= 0.326271186440678
# Test Recall LB= 0.3979328165374677
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6410336239103362
# Train F1 Score LB = 0.5241436236070985
# Train Precision LB= 0.7772337821297429
# Train Recall LB= 0.3953922789539228
#
# Test Balanced Score LB= 0.6420179841999659
# Test F1 Score LB= 0.3585564610011641
# Test Precision LB= 0.326271186440678
# Test Recall LB= 0.3979328165374677
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6410336239103362
# Train F1 Score LB = 0.5241436236070985
# Train Precision LB= 0.7772337821297429
# Train Recall LB= 0.3953922789539228
#
# Test Balanced Score LB= 0.6420179841999659
# Test F1 Score LB= 0.3585564610011641
# Test Precision LB= 0.326271186440678
# Test Recall LB= 0.3979328165374677
#
#
#  3.333 % Done
# Number of Estimators = 50 Depth = 2
#
# Train Balanced Accuracy XGB = 0.7129514321295143
# Train F1 Score XGB = 0.6955085865257595
# Train Precision XGB= 0.740506329113924
# Train Recall XGB= 0.6556662515566625
#
# Test Balanced Score XGB = 0.6583682244582159
# Test F1 Score XGB = 0.33045977011494254
# Test Precision XGB= 0.22885572139303484
# Test Recall XGB= 0.5943152454780362
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7085927770859277
# Train F1 Score LB = 0.7212626563430614
# Train Precision LB= 0.6912100456621004
# Train Recall LB= 0.7540473225404732
#
# Test Balanced Score LB= 0.6552867920896175
# Test F1 Score LB= 0.3104238258877434
# Test Precision LB= 0.199411331861663
# Test Recall LB= 0.7002583979328165
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7085927770859277
# Train F1 Score LB = 0.7212626563430614
# Train Precision LB= 0.6912100456621004
# Train Recall LB= 0.7540473225404732
#
# Test Balanced Score LB= 0.6552867920896175
# Test F1 Score LB= 0.3104238258877434
# Test Precision LB= 0.199411331861663
# Test Recall LB= 0.7002583979328165
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7085927770859277
# Train F1 Score LB = 0.7212626563430614
# Train Precision LB= 0.6912100456621004
# Train Recall LB= 0.7540473225404732
#
# Test Balanced Score LB= 0.6552867920896175
# Test F1 Score LB= 0.3104238258877434
# Test Precision LB= 0.199411331861663
# Test Recall LB= 0.7002583979328165
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7120174346201743
# Train F1 Score LB = 0.694214876033058
# Train Precision LB= 0.7399577167019028
# Train Recall LB= 0.6537982565379825
#
# Test Balanced Score LB= 0.6614510450678572
# Test F1 Score LB= 0.334056399132321
# Test Precision LB= 0.2319277108433735
# Test Recall LB= 0.5968992248062015
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7120174346201743
# Train F1 Score LB = 0.694214876033058
# Train Precision LB= 0.7399577167019028
# Train Recall LB= 0.6537982565379825
#
# Test Balanced Score LB= 0.6614510450678572
# Test F1 Score LB= 0.334056399132321
# Test Precision LB= 0.2319277108433735
# Test Recall LB= 0.5968992248062015
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7120174346201743
# Train F1 Score LB = 0.694214876033058
# Train Precision LB= 0.7399577167019028
# Train Recall LB= 0.6537982565379825
#
# Test Balanced Score LB= 0.6614510450678572
# Test F1 Score LB= 0.334056399132321
# Test Precision LB= 0.2319277108433735
# Test Recall LB= 0.5968992248062015
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6952054794520548
# Train F1 Score LB = 0.6438704983630411
# Train Precision LB= 0.7742782152230971
# Train Recall LB= 0.5510585305105853
#
# Test Balanced Score LB= 0.655156297431569
# Test F1 Score LB= 0.34900542495479203
# Test Precision LB= 0.26842837273991654
# Test Recall LB= 0.49870801033591733
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6952054794520548
# Train F1 Score LB = 0.6438704983630411
# Train Precision LB= 0.7742782152230971
# Train Recall LB= 0.5510585305105853
#
# Test Balanced Score LB= 0.655156297431569
# Test F1 Score LB= 0.34900542495479203
# Test Precision LB= 0.26842837273991654
# Test Recall LB= 0.49870801033591733
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6952054794520548
# Train F1 Score LB = 0.6438704983630411
# Train Precision LB= 0.7742782152230971
# Train Recall LB= 0.5510585305105853
#
# Test Balanced Score LB= 0.655156297431569
# Test F1 Score LB= 0.34900542495479203
# Test Precision LB= 0.26842837273991654
# Test Recall LB= 0.49870801033591733
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6696762141967622
# Train F1 Score LB = 0.5757696921231508
# Train Precision LB= 0.8044692737430168
# Train Recall LB= 0.44831880448318806
#
# Test Balanced Score LB= 0.6389481205067264
# Test F1 Score LB= 0.34763476347634764
# Test Precision LB= 0.30268199233716475
# Test Recall LB= 0.4082687338501292
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6696762141967622
# Train F1 Score LB = 0.5757696921231508
# Train Precision LB= 0.8044692737430168
# Train Recall LB= 0.44831880448318806
#
# Test Balanced Score LB= 0.6389481205067264
# Test F1 Score LB= 0.34763476347634764
# Test Precision LB= 0.30268199233716475
# Test Recall LB= 0.4082687338501292
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6696762141967622
# Train F1 Score LB = 0.5757696921231508
# Train Precision LB= 0.8044692737430168
# Train Recall LB= 0.44831880448318806
#
# Test Balanced Score LB= 0.6389481205067264
# Test F1 Score LB= 0.34763476347634764
# Test Precision LB= 0.30268199233716475
# Test Recall LB= 0.4082687338501292
#
#
#  6.667 % Done
# Number of Estimators = 50 Depth = 3
#
# Train Balanced Accuracy XGB = 0.7674346201743463
# Train F1 Score XGB = 0.7565982404692082
# Train Precision XGB= 0.7935748462064252
# Train Recall XGB= 0.7229140722291407
#
# Test Balanced Score XGB = 0.6562067331541577
# Test F1 Score XGB = 0.3234100135317997
# Test Precision XGB= 0.21906507791017416
# Test Recall XGB= 0.6175710594315246
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7608966376089663
# Train F1 Score LB = 0.7697841726618706
# Train Precision LB= 0.7421965317919075
# Train Recall LB= 0.7995018679950187
#
# Test Balanced Score LB= 0.651449231099561
# Test F1 Score LB= 0.3072529982866933
# Test Precision LB= 0.1972140762463343
# Test Recall LB= 0.6950904392764858
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7608966376089663
# Train F1 Score LB = 0.7697841726618706
# Train Precision LB= 0.7421965317919075
# Train Recall LB= 0.7995018679950187
#
# Test Balanced Score LB= 0.651449231099561
# Test F1 Score LB= 0.3072529982866933
# Test Precision LB= 0.1972140762463343
# Test Recall LB= 0.6950904392764858
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7608966376089663
# Train F1 Score LB = 0.7697841726618706
# Train Precision LB= 0.7421965317919075
# Train Recall LB= 0.7995018679950187
#
# Test Balanced Score LB= 0.651449231099561
# Test F1 Score LB= 0.3072529982866933
# Test Precision LB= 0.1972140762463343
# Test Recall LB= 0.6950904392764858
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7658779576587795
# Train F1 Score LB = 0.7548891786179922
# Train Precision LB= 0.7920656634746922
# Train Recall LB= 0.7210460772104608
#
# Test Balanced Score LB= 0.6530086885379416
# Test F1 Score LB= 0.3212576896787423
# Test Precision LB= 0.2184014869888476
# Test Recall LB= 0.6072351421188631
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7658779576587795
# Train F1 Score LB = 0.7548891786179922
# Train Precision LB= 0.7920656634746922
# Train Recall LB= 0.7210460772104608
#
# Test Balanced Score LB= 0.6530086885379416
# Test F1 Score LB= 0.3212576896787423
# Test Precision LB= 0.2184014869888476
# Test Recall LB= 0.6072351421188631
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7658779576587795
# Train F1 Score LB = 0.7548891786179922
# Train Precision LB= 0.7920656634746922
# Train Recall LB= 0.7210460772104608
#
# Test Balanced Score LB= 0.6530086885379416
# Test F1 Score LB= 0.3212576896787423
# Test Precision LB= 0.2184014869888476
# Test Recall LB= 0.6072351421188631
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.7531133250311333
# Train F1 Score LB = 0.7182948490230906
# Train Precision LB= 0.8362282878411911
# Train Recall LB= 0.6295143212951432
#
# Test Balanced Score LB= 0.6566532840230115
# Test F1 Score LB= 0.34343434343434354
# Test Precision LB= 0.2546816479400749
# Test Recall LB= 0.5271317829457365
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.7531133250311333
# Train F1 Score LB = 0.7182948490230906
# Train Precision LB= 0.8362282878411911
# Train Recall LB= 0.6295143212951432
#
# Test Balanced Score LB= 0.6566532840230115
# Test F1 Score LB= 0.34343434343434354
# Test Precision LB= 0.2546816479400749
# Test Recall LB= 0.5271317829457365
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.7531133250311333
# Train F1 Score LB = 0.7182948490230906
# Train Precision LB= 0.8362282878411911
# Train Recall LB= 0.6295143212951432
#
# Test Balanced Score LB= 0.6566532840230115
# Test F1 Score LB= 0.34343434343434354
# Test Precision LB= 0.2546816479400749
# Test Recall LB= 0.5271317829457365
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.7263387297633873
# Train F1 Score LB = 0.6602241979126401
# Train Precision LB= 0.8705402650356778
# Train Recall LB= 0.5317559153175592
#
# Test Balanced Score LB= 0.6373877375743171
# Test F1 Score LB= 0.3391933815925543
# Test Precision LB= 0.2827586206896552
# Test Recall LB= 0.42377260981912146
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.7263387297633873
# Train F1 Score LB = 0.6602241979126401
# Train Precision LB= 0.8705402650356778
# Train Recall LB= 0.5317559153175592
#
# Test Balanced Score LB= 0.6373877375743171
# Test F1 Score LB= 0.3391933815925543
# Test Precision LB= 0.2827586206896552
# Test Recall LB= 0.42377260981912146
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.7263387297633873
# Train F1 Score LB = 0.6602241979126401
# Train Precision LB= 0.8705402650356778
# Train Recall LB= 0.5317559153175592
#
# Test Balanced Score LB= 0.6373877375743171
# Test F1 Score LB= 0.3391933815925543
# Test Precision LB= 0.2827586206896552
# Test Recall LB= 0.42377260981912146
#
#
#  10.0 % Done
# Number of Estimators = 50 Depth = 5
#
# Train Balanced Accuracy XGB = 0.9299501867995019
# Train F1 Score XGB = 0.9264465511605099
# Train Precision XGB= 0.975223675154852
# Train Recall XGB= 0.8823163138231631
#
# Test Balanced Score XGB = 0.6432997934297328
# Test F1 Score XGB = 0.3101391650099404
# Test Precision XGB= 0.20855614973262032
# Test Recall XGB= 0.6046511627906976
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9190535491905355
# Train F1 Score LB = 0.9185973700688791
# Train Precision LB= 0.9238035264483627
# Train Recall LB= 0.9134495641344956
#
# Test Balanced Score LB= 0.6517051301985
# Test F1 Score LB= 0.30690826727066817
# Test Precision LB= 0.19651921682378534
# Test Recall LB= 0.7002583979328165
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9190535491905355
# Train F1 Score LB = 0.9185973700688791
# Train Precision LB= 0.9238035264483627
# Train Recall LB= 0.9134495641344956
#
# Test Balanced Score LB= 0.6517051301985
# Test F1 Score LB= 0.30690826727066817
# Test Precision LB= 0.19651921682378534
# Test Recall LB= 0.7002583979328165
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9190535491905355
# Train F1 Score LB = 0.9185973700688791
# Train Precision LB= 0.9238035264483627
# Train Recall LB= 0.9134495641344956
#
# Test Balanced Score LB= 0.6517051301985
# Test F1 Score LB= 0.30690826727066817
# Test Precision LB= 0.19651921682378534
# Test Recall LB= 0.7002583979328165
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9199875466998755
# Train F1 Score LB = 0.9157653228449688
# Train Precision LB= 0.9667820069204153
# Train Recall LB= 0.8698630136986302
#
# Test Balanced Score LB= 0.6493631675588429
# Test F1 Score LB= 0.3156498673740053
# Test Precision LB= 0.21231043710972347
# Test Recall LB= 0.6149870801033591
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9199875466998755
# Train F1 Score LB = 0.9157653228449688
# Train Precision LB= 0.9667820069204153
# Train Recall LB= 0.8698630136986302
#
# Test Balanced Score LB= 0.6493631675588429
# Test F1 Score LB= 0.3156498673740053
# Test Precision LB= 0.21231043710972347
# Test Recall LB= 0.6149870801033591
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9199875466998755
# Train F1 Score LB = 0.9157653228449688
# Train Precision LB= 0.9667820069204153
# Train Recall LB= 0.8698630136986302
#
# Test Balanced Score LB= 0.6493631675588429
# Test F1 Score LB= 0.3156498673740053
# Test Precision LB= 0.21231043710972347
# Test Recall LB= 0.6149870801033591
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9062889165628891
# Train F1 Score LB = 0.897931502204137
# Train Precision LB= 0.9858525688756515
# Train Recall LB= 0.8244084682440846
#
# Test Balanced Score LB= 0.6469957538333962
# Test F1 Score LB= 0.32579890880748247
# Test Precision LB= 0.23325892857142858
# Test Recall LB= 0.5400516795865633
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9062889165628891
# Train F1 Score LB = 0.897931502204137
# Train Precision LB= 0.9858525688756515
# Train Recall LB= 0.8244084682440846
#
# Test Balanced Score LB= 0.6469957538333962
# Test F1 Score LB= 0.32579890880748247
# Test Precision LB= 0.23325892857142858
# Test Recall LB= 0.5400516795865633
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9062889165628891
# Train F1 Score LB = 0.897931502204137
# Train Precision LB= 0.9858525688756515
# Train Recall LB= 0.8244084682440846
#
# Test Balanced Score LB= 0.6469957538333962
# Test F1 Score LB= 0.32579890880748247
# Test Precision LB= 0.23325892857142858
# Test Recall LB= 0.5400516795865633
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.8776463262764633
# Train F1 Score LB = 0.8615709756956675
# Train Precision LB= 0.991889699918897
# Train Recall LB= 0.7615193026151931
#
# Test Balanced Score LB= 0.638283615794111
# Test F1 Score LB= 0.3305478180129991
# Test Precision LB= 0.2579710144927536
# Test Recall LB= 0.4599483204134367
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.8776463262764633
# Train F1 Score LB = 0.8615709756956675
# Train Precision LB= 0.991889699918897
# Train Recall LB= 0.7615193026151931
#
# Test Balanced Score LB= 0.638283615794111
# Test F1 Score LB= 0.3305478180129991
# Test Precision LB= 0.2579710144927536
# Test Recall LB= 0.4599483204134367
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.8776463262764633
# Train F1 Score LB = 0.8615709756956675
# Train Precision LB= 0.991889699918897
# Train Recall LB= 0.7615193026151931
#
# Test Balanced Score LB= 0.638283615794111
# Test F1 Score LB= 0.3305478180129991
# Test Precision LB= 0.2579710144927536
# Test Recall LB= 0.4599483204134367
#
#
#  13.333 % Done
# Number of Estimators = 50 Depth = 7
#
# Train Balanced Accuracy XGB = 0.9971980074719801
# Train F1 Score XGB = 0.9971901342491414
# Train Precision XGB= 1.0
# Train Recall XGB= 0.9943960149439601
#
# Test Balanced Score XGB = 0.6231781650044794
# Test F1 Score XGB = 0.2913128674069236
# Test Precision XGB= 0.19493006993006992
# Test Recall XGB= 0.5762273901808785
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9582814445828145
# Train F1 Score LB = 0.9582294264339153
# Train Precision LB= 0.9594257178526842
# Train Recall LB= 0.9570361145703612
#
# Test Balanced Score LB= 0.6465755795443608
# Test F1 Score LB= 0.3028248587570621
# Test Precision LB= 0.19378163412870572
# Test Recall LB= 0.6925064599483204
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9582814445828145
# Train F1 Score LB = 0.9582294264339153
# Train Precision LB= 0.9594257178526842
# Train Recall LB= 0.9570361145703612
#
# Test Balanced Score LB= 0.6465755795443608
# Test F1 Score LB= 0.3028248587570621
# Test Precision LB= 0.19378163412870572
# Test Recall LB= 0.6925064599483204
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9582814445828145
# Train F1 Score LB = 0.9582294264339153
# Train Precision LB= 0.9594257178526842
# Train Recall LB= 0.9570361145703612
#
# Test Balanced Score LB= 0.6465755795443608
# Test F1 Score LB= 0.3028248587570621
# Test Precision LB= 0.19378163412870572
# Test Recall LB= 0.6925064599483204
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9570361145703612
# Train F1 Score LB = 0.955966815571155
# Train Precision LB= 0.9803664921465969
# Train Recall LB= 0.9327521793275217
#
# Test Balanced Score LB= 0.6542881840326367
# Test F1 Score LB= 0.31859557867360205
# Test Precision LB= 0.21285838401390095
# Test Recall LB= 0.6330749354005168
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9570361145703612
# Train F1 Score LB = 0.955966815571155
# Train Precision LB= 0.9803664921465969
# Train Recall LB= 0.9327521793275217
#
# Test Balanced Score LB= 0.6542881840326367
# Test F1 Score LB= 0.31859557867360205
# Test Precision LB= 0.21285838401390095
# Test Recall LB= 0.6330749354005168
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9570361145703612
# Train F1 Score LB = 0.955966815571155
# Train Precision LB= 0.9803664921465969
# Train Recall LB= 0.9327521793275217
#
# Test Balanced Score LB= 0.6542881840326367
# Test F1 Score LB= 0.31859557867360205
# Test Precision LB= 0.21285838401390095
# Test Recall LB= 0.6330749354005168
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9455168119551681
# Train F1 Score LB = 0.942829140803659
# Train Precision LB= 0.9917525773195877
# Train Recall LB= 0.8985056039850561
#
# Test Balanced Score LB= 0.6509614957464294
# Test F1 Score LB= 0.32613551749813846
# Test Precision LB= 0.2290794979079498
# Test Recall LB= 0.5658914728682171
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9455168119551681
# Train F1 Score LB = 0.942829140803659
# Train Precision LB= 0.9917525773195877
# Train Recall LB= 0.8985056039850561
#
# Test Balanced Score LB= 0.6509614957464294
# Test F1 Score LB= 0.32613551749813846
# Test Precision LB= 0.2290794979079498
# Test Recall LB= 0.5658914728682171
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9455168119551681
# Train F1 Score LB = 0.942829140803659
# Train Precision LB= 0.9917525773195877
# Train Recall LB= 0.8985056039850561
#
# Test Balanced Score LB= 0.6509614957464294
# Test F1 Score LB= 0.32613551749813846
# Test Precision LB= 0.2290794979079498
# Test Recall LB= 0.5658914728682171
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.923412204234122
# Train F1 Score LB = 0.9173387096774193
# Train Precision LB= 0.9963503649635036
# Train Recall LB= 0.8499377334993773
#
# Test Balanced Score LB= 0.6451276441364401
# Test F1 Score LB= 0.3321858864027538
# Test Precision LB= 0.24903225806451612
# Test Recall LB= 0.49870801033591733
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.923412204234122
# Train F1 Score LB = 0.9173387096774193
# Train Precision LB= 0.9963503649635036
# Train Recall LB= 0.8499377334993773
#
# Test Balanced Score LB= 0.6451276441364401
# Test F1 Score LB= 0.3321858864027538
# Test Precision LB= 0.24903225806451612
# Test Recall LB= 0.49870801033591733
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.923412204234122
# Train F1 Score LB = 0.9173387096774193
# Train Precision LB= 0.9963503649635036
# Train Recall LB= 0.8499377334993773
#
# Test Balanced Score LB= 0.6451276441364401
# Test F1 Score LB= 0.3321858864027538
# Test Precision LB= 0.24903225806451612
# Test Recall LB= 0.49870801033591733
#
#
#  16.667 % Done
# Number of Estimators = 50 Depth = 10
#
# Train Balanced Accuracy XGB = 1.0
# Train F1 Score XGB = 1.0
# Train Precision XGB= 1.0
# Train Recall XGB= 1.0
#
# Test Balanced Score XGB = 0.6354071803528724
# Test F1 Score XGB = 0.3029100529100529
# Test Precision XGB= 0.20355555555555555
# Test Recall XGB= 0.5917312661498708
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9707347447073474
# Train F1 Score LB = 0.9709876543209877
# Train Precision LB= 0.9626682986536108
# Train Recall LB= 0.9794520547945206
#
# Test Balanced Score LB= 0.643275267837972
# Test F1 Score LB= 0.3002257336343115
# Test Precision LB= 0.192057761732852
# Test Recall LB= 0.6873385012919897
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9707347447073474
# Train F1 Score LB = 0.9709876543209877
# Train Precision LB= 0.9626682986536108
# Train Recall LB= 0.9794520547945206
#
# Test Balanced Score LB= 0.643275267837972
# Test F1 Score LB= 0.3002257336343115
# Test Precision LB= 0.192057761732852
# Test Recall LB= 0.6873385012919897
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9707347447073474
# Train F1 Score LB = 0.9709876543209877
# Train Precision LB= 0.9626682986536108
# Train Recall LB= 0.9794520547945206
#
# Test Balanced Score LB= 0.643275267837972
# Test F1 Score LB= 0.3002257336343115
# Test Precision LB= 0.192057761732852
# Test Recall LB= 0.6873385012919897
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.966376089663761
# Train F1 Score LB = 0.9659520807061791
# Train Precision LB= 0.9782886334610472
# Train Recall LB= 0.9539227895392279
#
# Test Balanced Score LB= 0.6494529404796281
# Test F1 Score LB= 0.3130990415335463
# Test Precision LB= 0.20797962648556875
# Test Recall LB= 0.6330749354005168
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.966376089663761
# Train F1 Score LB = 0.9659520807061791
# Train Precision LB= 0.9782886334610472
# Train Recall LB= 0.9539227895392279
#
# Test Balanced Score LB= 0.6494529404796281
# Test F1 Score LB= 0.3130990415335463
# Test Precision LB= 0.20797962648556875
# Test Recall LB= 0.6330749354005168
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.966376089663761
# Train F1 Score LB = 0.9659520807061791
# Train Precision LB= 0.9782886334610472
# Train Recall LB= 0.9539227895392279
#
# Test Balanced Score LB= 0.6494529404796281
# Test F1 Score LB= 0.3130990415335463
# Test Precision LB= 0.20797962648556875
# Test Recall LB= 0.6330749354005168
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9561021170610211
# Train F1 Score LB = 0.9545307965172526
# Train Precision LB= 0.9899665551839465
# Train Recall LB= 0.9215442092154421
#
# Test Balanced Score LB= 0.6498485891769026
# Test F1 Score LB= 0.3251304996271439
# Test Precision LB= 0.22851153039832284
# Test Recall LB= 0.5633074935400517
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9561021170610211
# Train F1 Score LB = 0.9545307965172526
# Train Precision LB= 0.9899665551839465
# Train Recall LB= 0.9215442092154421
#
# Test Balanced Score LB= 0.6498485891769026
# Test F1 Score LB= 0.3251304996271439
# Test Precision LB= 0.22851153039832284
# Test Recall LB= 0.5633074935400517
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9561021170610211
# Train F1 Score LB = 0.9545307965172526
# Train Precision LB= 0.9899665551839465
# Train Recall LB= 0.9215442092154421
#
# Test Balanced Score LB= 0.6498485891769026
# Test F1 Score LB= 0.3251304996271439
# Test Precision LB= 0.22851153039832284
# Test Recall LB= 0.5633074935400517
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9389788293897883
# Train F1 Score LB = 0.9353135313531352
# Train Precision LB= 0.9950842696629213
# Train Recall LB= 0.8823163138231631
#
# Test Balanced Score LB= 0.650359461880752
# Test F1 Score LB= 0.34005258545135847
# Test Precision LB= 0.2572944297082228
# Test Recall LB= 0.5012919896640827
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9389788293897883
# Train F1 Score LB = 0.9353135313531352
# Train Precision LB= 0.9950842696629213
# Train Recall LB= 0.8823163138231631
#
# Test Balanced Score LB= 0.650359461880752
# Test F1 Score LB= 0.34005258545135847
# Test Precision LB= 0.2572944297082228
# Test Recall LB= 0.5012919896640827
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9389788293897883
# Train F1 Score LB = 0.9353135313531352
# Train Precision LB= 0.9950842696629213
# Train Recall LB= 0.8823163138231631
#
# Test Balanced Score LB= 0.650359461880752
# Test F1 Score LB= 0.34005258545135847
# Test Precision LB= 0.2572944297082228
# Test Recall LB= 0.5012919896640827
#
#
#  20.0 % Done
# Number of Estimators = 150 Depth = 1
#
# Train Balanced Accuracy XGB = 0.702988792029888
# Train F1 Score XGB = 0.6770480704129994
# Train Precision XGB= 0.7418397626112759
# Train Recall XGB= 0.6226650062266501
#
# Test Balanced Score XGB = 0.6580225524384917
# Test F1 Score XGB = 0.33484848484848484
# Test Precision XGB= 0.23687031082529475
# Test Recall XGB= 0.5710594315245479
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7067247820672478
# Train F1 Score LB = 0.7131546894031668
# Train Precision LB= 0.6978545887961859
# Train Recall LB= 0.7291407222914073
#
# Test Balanced Score LB= 0.6567703590176437
# Test F1 Score LB= 0.31459330143540676
# Test Precision LB= 0.2046692607003891
# Test Recall LB= 0.6795865633074936
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7067247820672478
# Train F1 Score LB = 0.7131546894031668
# Train Precision LB= 0.6978545887961859
# Train Recall LB= 0.7291407222914073
#
# Test Balanced Score LB= 0.6567703590176437
# Test F1 Score LB= 0.31459330143540676
# Test Precision LB= 0.2046692607003891
# Test Recall LB= 0.6795865633074936
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7067247820672478
# Train F1 Score LB = 0.7131546894031668
# Train Precision LB= 0.6978545887961859
# Train Recall LB= 0.7291407222914073
#
# Test Balanced Score LB= 0.6567703590176437
# Test F1 Score LB= 0.31459330143540676
# Test Precision LB= 0.2046692607003891
# Test Recall LB= 0.6795865633074936
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.6995641344956414
# Train F1 Score LB = 0.6727704306544592
# Train Precision LB= 0.7386448250186151
# Train Recall LB= 0.6176836861768369
#
# Test Balanced Score LB= 0.6579202853483189
# Test F1 Score LB= 0.33358264771877344
# Test Precision LB= 0.23473684210526316
# Test Recall LB= 0.5762273901808785
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.6995641344956414
# Train F1 Score LB = 0.6727704306544592
# Train Precision LB= 0.7386448250186151
# Train Recall LB= 0.6176836861768369
#
# Test Balanced Score LB= 0.6579202853483189
# Test F1 Score LB= 0.33358264771877344
# Test Precision LB= 0.23473684210526316
# Test Recall LB= 0.5762273901808785
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.6995641344956414
# Train F1 Score LB = 0.6727704306544592
# Train Precision LB= 0.7386448250186151
# Train Recall LB= 0.6176836861768369
#
# Test Balanced Score LB= 0.6579202853483189
# Test F1 Score LB= 0.33358264771877344
# Test Precision LB= 0.23473684210526316
# Test Recall LB= 0.5762273901808785
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6827521793275217
# Train F1 Score LB = 0.6235685260435907
# Train Precision LB= 0.7665758401453224
# Train Recall LB= 0.5255292652552926
#
# Test Balanced Score LB= 0.6555399147064703
# Test F1 Score LB= 0.35294117647058826
# Test Precision LB= 0.27631578947368424
# Test Recall LB= 0.4883720930232558
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6827521793275217
# Train F1 Score LB = 0.6235685260435907
# Train Precision LB= 0.7665758401453224
# Train Recall LB= 0.5255292652552926
#
# Test Balanced Score LB= 0.6555399147064703
# Test F1 Score LB= 0.35294117647058826
# Test Precision LB= 0.27631578947368424
# Test Recall LB= 0.4883720930232558
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.6827521793275217
# Train F1 Score LB = 0.6235685260435907
# Train Precision LB= 0.7665758401453224
# Train Recall LB= 0.5255292652552926
#
# Test Balanced Score LB= 0.6555399147064703
# Test F1 Score LB= 0.35294117647058826
# Test Precision LB= 0.27631578947368424
# Test Recall LB= 0.4883720930232558
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6581569115815691
# Train F1 Score LB = 0.5628980891719745
# Train Precision LB= 0.7803532008830022
# Train Recall LB= 0.4402241594022416
#
# Test Balanced Score LB= 0.6457662350162516
# Test F1 Score LB= 0.35745614035087714
# Test Precision LB= 0.31047619047619046
# Test Recall LB= 0.42118863049095606
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6581569115815691
# Train F1 Score LB = 0.5628980891719745
# Train Precision LB= 0.7803532008830022
# Train Recall LB= 0.4402241594022416
#
# Test Balanced Score LB= 0.6457662350162516
# Test F1 Score LB= 0.35745614035087714
# Test Precision LB= 0.31047619047619046
# Test Recall LB= 0.42118863049095606
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.6581569115815691
# Train F1 Score LB = 0.5628980891719745
# Train Precision LB= 0.7803532008830022
# Train Recall LB= 0.4402241594022416
#
# Test Balanced Score LB= 0.6457662350162516
# Test F1 Score LB= 0.35745614035087714
# Test Precision LB= 0.31047619047619046
# Test Recall LB= 0.42118863049095606
#
#
#  23.333 % Done
# Number of Estimators = 150 Depth = 2
#
# Train Balanced Accuracy XGB = 0.7761519302615193
# Train F1 Score XGB = 0.7652628142344106
# Train Precision XGB= 0.8043925875085792
# Train Recall XGB= 0.7297633872976339
#
# Test Balanced Score XGB = 0.6607476696060357
# Test F1 Score XGB = 0.3305322128851541
# Test Precision XGB= 0.22670509125840538
# Test Recall XGB= 0.6098191214470284
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7649439601494397
# Train F1 Score LB = 0.7737488762361402
# Train Precision LB= 0.7458116695551704
# Train Recall LB= 0.8038605230386052
#
# Test Balanced Score LB= 0.6465626226279588
# Test F1 Score LB= 0.3042220936957779
# Test Precision LB= 0.19597615499254845
# Test Recall LB= 0.6795865633074936
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7649439601494397
# Train F1 Score LB = 0.7737488762361402
# Train Precision LB= 0.7458116695551704
# Train Recall LB= 0.8038605230386052
#
# Test Balanced Score LB= 0.6465626226279588
# Test F1 Score LB= 0.3042220936957779
# Test Precision LB= 0.19597615499254845
# Test Recall LB= 0.6795865633074936
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.7649439601494397
# Train F1 Score LB = 0.7737488762361402
# Train Precision LB= 0.7458116695551704
# Train Recall LB= 0.8038605230386052
#
# Test Balanced Score LB= 0.6465626226279588
# Test F1 Score LB= 0.3042220936957779
# Test Precision LB= 0.19597615499254845
# Test Recall LB= 0.6795865633074936
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7708592777085927
# Train F1 Score LB = 0.7602605863192182
# Train Precision LB= 0.7971311475409836
# Train Recall LB= 0.7266500622665006
#
# Test Balanced Score LB= 0.6561937762377557
# Test F1 Score LB= 0.325678496868476
# Test Precision LB= 0.22285714285714286
# Test Recall LB= 0.6046511627906976
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7708592777085927
# Train F1 Score LB = 0.7602605863192182
# Train Precision LB= 0.7971311475409836
# Train Recall LB= 0.7266500622665006
# Test Balanced Score LB= 0.6561937762377557
# Test F1 Score LB= 0.325678496868476
# Test Precision LB= 0.22285714285714286
# Test Recall LB= 0.6046511627906976
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.7708592777085927
# Train F1 Score LB = 0.7602605863192182
# Train Precision LB= 0.7971311475409836
# Train Recall LB= 0.7266500622665006
#
# Test Balanced Score LB= 0.6561937762377557
# Test F1 Score LB= 0.325678496868476
# Test Precision LB= 0.22285714285714286
# Test Recall LB= 0.6046511627906976
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.7605853051058531
# Train F1 Score LB = 0.7293206617388245
# Train Precision LB= 0.8388663967611336
# Train Recall LB= 0.6450809464508095
#
# Test Balanced Score LB= 0.6533913803188142
# Test F1 Score LB= 0.33889816360601005
# Test Precision LB= 0.25030826140567203
# Test Recall LB= 0.524547803617571
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.7605853051058531
# Train F1 Score LB = 0.7293206617388245
# Train Precision LB= 0.8388663967611336
# Train Recall LB= 0.6450809464508095
#
# Test Balanced Score LB= 0.6533913803188142
# Test F1 Score LB= 0.33889816360601005
# Test Precision LB= 0.25030826140567203
# Test Recall LB= 0.524547803617571
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.7605853051058531
# Train F1 Score LB = 0.7293206617388245
# Train Precision LB= 0.8388663967611336
# Train Recall LB= 0.6450809464508095
#
# Test Balanced Score LB= 0.6533913803188142
# Test F1 Score LB= 0.33889816360601005
# Test Precision LB= 0.25030826140567203
# Test Recall LB= 0.524547803617571
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.7397260273972603
# Train F1 Score LB = 0.68212927756654
# Train Precision LB= 0.8759765625
# Train Recall LB= 0.5585305105853051
#
# Test Balanced Score LB= 0.6422359380437278
# Test F1 Score LB= 0.3445463812436289
# Test Precision LB= 0.2845117845117845
# Test Recall LB= 0.43669250645994834
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.7397260273972603
# Train F1 Score LB = 0.68212927756654
# Train Precision LB= 0.8759765625
# Train Recall LB= 0.5585305105853051
#
# Test Balanced Score LB= 0.6422359380437278
# Test F1 Score LB= 0.3445463812436289
# Test Precision LB= 0.2845117845117845
# Test Recall LB= 0.43669250645994834
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.7397260273972603
# Train F1 Score LB = 0.68212927756654
# Train Precision LB= 0.8759765625
# Train Recall LB= 0.5585305105853051
#
# Test Balanced Score LB= 0.6422359380437278
# Test F1 Score LB= 0.3445463812436289
# Test Precision LB= 0.2845117845117845
# Test Recall LB= 0.43669250645994834
#
#
#  26.667 % Done
# Number of Estimators = 150 Depth = 3
#
# Train Balanced Accuracy XGB = 0.887920298879203
# Train F1 Score XGB = 0.8826597131681878
# Train Precision XGB= 0.9261285909712722
# Train Recall XGB= 0.8430884184308842
#
# Test Balanced Score XGB = 0.6538786529249314
# Test F1 Score XGB = 0.32059020791415155
# Test Precision XGB= 0.2164855072463768
# Test Recall XGB= 0.6175710594315246
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.8776463262764633
# Train F1 Score LB = 0.8793368130181148
# Train Precision LB= 0.8673531193216233
# Train Recall LB= 0.8916562889165629
#
# Test Balanced Score LB= 0.6628212389773662
# Test F1 Score LB= 0.3163323782234957
# Test Precision LB= 0.203240058910162
# Test Recall LB= 0.7131782945736435
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.8776463262764633
# Train F1 Score LB = 0.8793368130181148
# Train Precision LB= 0.8673531193216233
# Train Recall LB= 0.8916562889165629
#
# Test Balanced Score LB= 0.6628212389773662
# Test F1 Score LB= 0.3163323782234957
# Test Precision LB= 0.203240058910162
# Test Recall LB= 0.7131782945736435
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.8776463262764633
# Train F1 Score LB = 0.8793368130181148
# Train Precision LB= 0.8673531193216233
# Train Recall LB= 0.8916562889165629
#
# Test Balanced Score LB= 0.6628212389773662
# Test F1 Score LB= 0.3163323782234957
# Test Precision LB= 0.203240058910162
# Test Recall LB= 0.7131782945736435
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.8810709838107098
# Train F1 Score LB = 0.8762151652624757
# Train Precision LB= 0.9135135135135135
# Train Recall LB= 0.8418430884184309
#
# Test Balanced Score LB= 0.658803669398725
# Test F1 Score LB= 0.3234714003944773
# Test Precision LB= 0.21693121693121692
# Test Recall LB= 0.6356589147286822
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.8810709838107098
# Train F1 Score LB = 0.8762151652624757
# Train Precision LB= 0.9135135135135135
# Train Recall LB= 0.8418430884184309
#
# Test Balanced Score LB= 0.658803669398725
# Test F1 Score LB= 0.3234714003944773
# Test Precision LB= 0.21693121693121692
# Test Recall LB= 0.6356589147286822
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.8810709838107098
# Train F1 Score LB = 0.8762151652624757
# Train Precision LB= 0.9135135135135135
# Train Recall LB= 0.8418430884184309
#
# Test Balanced Score LB= 0.658803669398725
# Test F1 Score LB= 0.3234714003944773
# Test Precision LB= 0.21693121693121692
# Test Recall LB= 0.6356589147286822
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.8679950186799502
# Train F1 Score LB = 0.8555858310626702
# Train Precision LB= 0.9443609022556391
# Train Recall LB= 0.7820672478206725
#
# Test Balanced Score LB= 0.653097535964698
# Test F1 Score LB= 0.33178294573643413
# Test Precision LB= 0.2369878183831672
# Test Recall LB= 0.5529715762273901
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.8679950186799502
# Train F1 Score LB = 0.8555858310626702
# Train Precision LB= 0.9443609022556391
# Train Recall LB= 0.7820672478206725
#
# Test Balanced Score LB= 0.653097535964698
# Test F1 Score LB= 0.33178294573643413
# Test Precision LB= 0.2369878183831672
# Test Recall LB= 0.5529715762273901
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.8679950186799502
# Train F1 Score LB = 0.8555858310626702
# Train Precision LB= 0.9443609022556391
# Train Recall LB= 0.7820672478206725
#
# Test Balanced Score LB= 0.653097535964698
# Test F1 Score LB= 0.33178294573643413
# Test Precision LB= 0.2369878183831672
# Test Recall LB= 0.5529715762273901
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.8412204234122043
# Train F1 Score LB = 0.816414686825054
# Train Precision LB= 0.9675767918088737
# Train Recall LB= 0.7061021170610212
#
# Test Balanced Score LB= 0.62824200558258
# Test F1 Score LB= 0.31684981684981683
# Test Precision LB= 0.2453900709219858
# Test Recall LB= 0.4470284237726098
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.8412204234122043
# Train F1 Score LB = 0.816414686825054
# Train Precision LB= 0.9675767918088737
# Train Recall LB= 0.7061021170610212
#
# Test Balanced Score LB= 0.62824200558258
# Test F1 Score LB= 0.31684981684981683
# Test Precision LB= 0.2453900709219858
# Test Recall LB= 0.4470284237726098
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.8412204234122043
# Train F1 Score LB = 0.816414686825054
# Train Precision LB= 0.9675767918088737
# Train Recall LB= 0.7061021170610212
#
# Test Balanced Score LB= 0.62824200558258
# Test F1 Score LB= 0.31684981684981683
# Test Precision LB= 0.2453900709219858
# Test Recall LB= 0.4470284237726098
#
#
#  30.0 % Done
# Number of Estimators = 150 Depth = 5
#
# Train Balanced Accuracy XGB = 1.0
# Train F1 Score XGB = 1.0
# Train Precision XGB= 1.0
# Train Recall XGB= 1.0
#
# Test Balanced Score XGB = 0.649695882662165
# Test F1 Score XGB = 0.3144899285250162
# Test Precision XGB= 0.21006944444444445
# Test Recall XGB= 0.6253229974160207
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9984433374844334
# Train F1 Score LB = 0.9984409105082631
# Train Precision LB= 1.0
# Train Recall LB= 0.9968866749688667
#
# Test Balanced Score LB= 0.6400004072173726
# Test F1 Score LB= 0.29867892016082714
# Test Precision LB= 0.19202363367799113
# Test Recall LB= 0.6718346253229974
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9984433374844334
# Train F1 Score LB = 0.9984409105082631
# Train Precision LB= 1.0
# Train Recall LB= 0.9968866749688667
#
# Test Balanced Score LB= 0.6400004072173726
# Test F1 Score LB= 0.29867892016082714
# Test Precision LB= 0.19202363367799113
# Test Recall LB= 0.6718346253229974
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9984433374844334
# Train F1 Score LB = 0.9984409105082631
# Train Precision LB= 1.0
# Train Recall LB= 0.9968866749688667
#
# Test Balanced Score LB= 0.6400004072173726
# Test F1 Score LB= 0.29867892016082714
# Test Precision LB= 0.19202363367799113
# Test Recall LB= 0.6718346253229974
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9975093399750934
# Train F1 Score LB = 0.9975031210986267
# Train Precision LB= 1.0
# Train Recall LB= 0.9950186799501868
#
# Test Balanced Score LB= 0.6454362963950157
# Test F1 Score LB= 0.30935709739019734
# Test Precision LB= 0.20523648648648649
# Test Recall LB= 0.627906976744186
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9975093399750934
# Train F1 Score LB = 0.9975031210986267
# Train Precision LB= 1.0
# Train Recall LB= 0.9950186799501868
#
# Test Balanced Score LB= 0.6454362963950157
# Test F1 Score LB= 0.30935709739019734
# Test Precision LB= 0.20523648648648649
# Test Recall LB= 0.627906976744186
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9975093399750934
# Train F1 Score LB = 0.9975031210986267
# Train Precision LB= 1.0
# Train Recall LB= 0.9950186799501868
#
# Test Balanced Score LB= 0.6454362963950157
# Test F1 Score LB= 0.30935709739019734
# Test Precision LB= 0.20523648648648649
# Test Recall LB= 0.627906976744186
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9943960149439601
# Train F1 Score LB = 0.9943644333124608
# Train Precision LB= 1.0
# Train Recall LB= 0.9887920298879203
#
# Test Balanced Score LB= 0.6428004894012425
# Test F1 Score LB= 0.3145907473309609
# Test Precision LB= 0.21709233791748528
# Test Recall LB= 0.5710594315245479
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9943960149439601
# Train F1 Score LB = 0.9943644333124608
# Train Precision LB= 1.0
# Train Recall LB= 0.9887920298879203
#
# Test Balanced Score LB= 0.6428004894012425
# Test F1 Score LB= 0.3145907473309609
# Test Precision LB= 0.21709233791748528
# Test Recall LB= 0.5710594315245479
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9943960149439601
# Train F1 Score LB = 0.9943644333124608
# Train Precision LB= 1.0
# Train Recall LB= 0.9887920298879203
#
# Test Balanced Score LB= 0.6428004894012425
# Test F1 Score LB= 0.3145907473309609
# Test Precision LB= 0.21709233791748528
# Test Recall LB= 0.5710594315245479
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9887920298879203
# Train F1 Score LB = 0.9886649874055417
# Train Precision LB= 1.0
# Train Recall LB= 0.9775840597758406
#
# Test Balanced Score LB= 0.6451151499670524
# Test F1 Score LB= 0.3268608414239482
# Test Precision LB= 0.23792697290930506
# Test Recall LB= 0.5219638242894057
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9887920298879203
# Train F1 Score LB = 0.9886649874055417
# Train Precision LB= 1.0
# Train Recall LB= 0.9775840597758406
#
# Test Balanced Score LB= 0.6451151499670524
# Test F1 Score LB= 0.3268608414239482
# Test Precision LB= 0.23792697290930506
# Test Recall LB= 0.5219638242894057
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9887920298879203
# Train F1 Score LB = 0.9886649874055417
# Train Precision LB= 1.0
# Train Recall LB= 0.9775840597758406
#
# Test Balanced Score LB= 0.6451151499670524
# Test F1 Score LB= 0.3268608414239482
# Test Precision LB= 0.23792697290930506
# Test Recall LB= 0.5219638242894057
#
#
#  33.333 % Done
# Number of Estimators = 150 Depth = 7
#
# Train Balanced Accuracy XGB = 1.0
# Train F1 Score XGB = 1.0
# Train Precision XGB= 1.0
# Train Recall XGB= 1.0
#
# Test Balanced Score XGB = 0.6395774564462511
# Test F1 Score XGB = 0.30559167750325095
# Test Precision XGB= 0.20417028670721113
# Test Recall XGB= 0.6072351421188631
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6333997838045948
# Test F1 Score LB= 0.2934097421203438
# Test Precision LB= 0.18851251840942562
# Test Recall LB= 0.661498708010336
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6333997838045948
# Test F1 Score LB= 0.2934097421203438
# Test Precision LB= 0.18851251840942562
# Test Recall LB= 0.661498708010336
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6333997838045948
# Test F1 Score LB= 0.2934097421203438
# Test Precision LB= 0.18851251840942562
# Test Recall LB= 0.661498708010336
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6348190288976255
# Test F1 Score LB= 0.2998102466793169
# Test Precision LB= 0.1984924623115578
# Test Recall LB= 0.6124031007751938
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6348190288976255
# Test F1 Score LB= 0.2998102466793169
# Test Precision LB= 0.1984924623115578
# Test Recall LB= 0.6124031007751938
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6348190288976255
# Test F1 Score LB= 0.2998102466793169
# Test Precision LB= 0.1984924623115578
# Test Recall LB= 0.6124031007751938
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6394363186068723
# Test F1 Score LB= 0.3100558659217877
# Test Precision LB= 0.21244019138755982
# Test Recall LB= 0.5736434108527132
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6394363186068723
# Test F1 Score LB= 0.3100558659217877
# Test Precision LB= 0.21244019138755982
# Test Recall LB= 0.5736434108527132
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# ...
# Train Balanced Score LB = 0.8567870485678706
# Train F1 Score LB = 0.8366477272727272
# Train Precision LB= 0.9735537190082645
# Train Recall LB= 0.7334993773349938
#
# Test Balanced Score LB= 0.6359684924812865
# Test F1 Score LB= 0.3236074270557029
# Test Precision LB= 0.24596774193548387
# Test Recall LB= 0.4728682170542636
#
#
#  66.667 % Done
# Number of Estimators = 500 Depth = 3
#
# Train Balanced Accuracy XGB = 0.9947073474470735
# Train F1 Score XGB = 0.994679186228482
# Train Precision XGB= 1.0
# Train Recall XGB= 0.9894146948941469
#
# Test Balanced Score XGB = 0.6419953095962625
# Test F1 Score XGB = 0.3059418457648546
# Test Precision XGB= 0.20251046025104602
# Test Recall XGB= 0.6253229974160207
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9937733499377335
# Train F1 Score LB = 0.9937578027465667
# Train Precision LB= 0.9962453066332916
# Train Recall LB= 0.9912826899128269
#
# Test Balanced Score LB= 0.6434543509325278
# Test F1 Score LB= 0.30039525691699603
# Test Precision LB= 0.19219653179190752
# Test Recall LB= 0.6873385012919897
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9937733499377335
# Train F1 Score LB = 0.9937578027465667
# Train Precision LB= 0.9962453066332916
# Train Recall LB= 0.9912826899128269
#
# Test Balanced Score LB= 0.6434543509325278
# Test F1 Score LB= 0.30039525691699603
# Test Precision LB= 0.19219653179190752
# Test Recall LB= 0.6873385012919897
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 0.9937733499377335
# Train F1 Score LB = 0.9937578027465667
# Train Precision LB= 0.9962453066332916
# Train Recall LB= 0.9912826899128269
#
# Test Balanced Score LB= 0.6434543509325278
# Test F1 Score LB= 0.30039525691699603
# Test Precision LB= 0.19219653179190752
# Test Recall LB= 0.6873385012919897
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9931506849315068
# Train F1 Score LB = 0.993103448275862
# Train Precision LB= 1.0
# Train Recall LB= 0.9863013698630136
#
# Test Balanced Score LB= 0.6298685613380423
# Test F1 Score LB= 0.29545454545454547
# Test Precision LB= 0.19548872180451127
# Test Recall LB= 0.6046511627906976
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9931506849315068
# Train F1 Score LB = 0.993103448275862
# Train Precision LB= 1.0
# Train Recall LB= 0.9863013698630136
#
# Test Balanced Score LB= 0.6298685613380423
# Test F1 Score LB= 0.29545454545454547
# Test Precision LB= 0.19548872180451127
# Test Recall LB= 0.6046511627906976
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 0.9931506849315068
# Train F1 Score LB = 0.993103448275862
# Train Precision LB= 1.0
# Train Recall LB= 0.9863013698630136
#
# Test Balanced Score LB= 0.6298685613380423
# Test F1 Score LB= 0.29545454545454547
# Test Precision LB= 0.19548872180451127
# Test Recall LB= 0.6046511627906976
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9853673723536738
# Train F1 Score LB = 0.9851500789889415
# Train Precision LB= 1.0
# Train Recall LB= 0.9707347447073474
#
# Test Balanced Score LB= 0.6343067679527332
# Test F1 Score LB= 0.3050139275766017
# Test Precision LB= 0.20877025738798857
# Test Recall LB= 0.5658914728682171
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9853673723536738
# Train F1 Score LB = 0.9851500789889415
# Train Precision LB= 1.0
# Train Recall LB= 0.9707347447073474
#
# Test Balanced Score LB= 0.6343067679527332
# Test F1 Score LB= 0.3050139275766017
# Test Precision LB= 0.20877025738798857
# Test Recall LB= 0.5658914728682171
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 0.9853673723536738
# Train F1 Score LB = 0.9851500789889415
# Train Precision LB= 1.0
# Train Recall LB= 0.9707347447073474
#
# Test Balanced Score LB= 0.6343067679527332
# Test F1 Score LB= 0.3050139275766017
# Test Precision LB= 0.20877025738798857
# Test Recall LB= 0.5658914728682171
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9754047322540473
# Train F1 Score LB = 0.974784551548037
# Train Precision LB= 1.0
# Train Recall LB= 0.9508094645080947
#
# Test Balanced Score LB= 0.6299953540199759
# Test F1 Score LB= 0.3067484662576687
# Test Precision LB= 0.21810250817884405
# Test Recall LB= 0.5167958656330749
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9754047322540473
# Train F1 Score LB = 0.974784551548037
# Train Precision LB= 1.0
# Train Recall LB= 0.9508094645080947
#
# Test Balanced Score LB= 0.6299953540199759
# Test F1 Score LB= 0.3067484662576687
# Test Precision LB= 0.21810250817884405
# Test Recall LB= 0.5167958656330749
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 0.9754047322540473
# Train F1 Score LB = 0.974784551548037
# Train Precision LB= 1.0
# Train Recall LB= 0.9508094645080947
#
# Test Balanced Score LB= 0.6299953540199759
# Test F1 Score LB= 0.3067484662576687
# Test Precision LB= 0.21810250817884405
# Test Recall LB= 0.5167958656330749
#
#
#  70.0 % Done
# Number of Estimators = 500 Depth = 5
#
# Train Balanced Accuracy XGB = 1.0
# Train F1 Score XGB = 1.0
# Train Precision XGB= 1.0
# Train Recall XGB= 1.0
#
# Test Balanced Score XGB = 0.6412021612136558
# Test F1 Score XGB = 0.3057324840764331
# Test Precision XGB= 0.2028740490278952
# Test Recall XGB= 0.6201550387596899
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6387593197248691
# Test F1 Score LB= 0.2998805256869773
# Test Precision LB= 0.19502719502719504
# Test Recall LB= 0.648578811369509
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6387593197248691
# Test F1 Score LB= 0.2998805256869773
# Test Precision LB= 0.19502719502719504
# Test Recall LB= 0.648578811369509
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6387593197248691
# Test F1 Score LB= 0.2998805256869773
# Test Precision LB= 0.19502719502719504
# Test Recall LB= 0.648578811369509
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6423918837875657
# Test F1 Score LB= 0.30604534005037787
# Test Precision LB= 0.20233139050791007
# Test Recall LB= 0.627906976744186
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6423918837875657
# Test F1 Score LB= 0.30604534005037787
# Test Precision LB= 0.20233139050791007
# Test Recall LB= 0.627906976744186
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6423918837875657
# Test F1 Score LB= 0.30604534005037787
# Test Precision LB= 0.20233139050791007
# Test Recall LB= 0.627906976744186
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6459476318458793
# Test F1 Score LB= 0.3135935397039031
# Test Precision LB= 0.21201091901728844
# Test Recall LB= 0.6020671834625323
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6459476318458793
# Test F1 Score LB= 0.3135935397039031
# Test Precision LB= 0.21201091901728844
# Test Recall LB= 0.6020671834625323
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6459476318458793
# Test F1 Score LB= 0.3135935397039031
# Test Precision LB= 0.21201091901728844
# Test Recall LB= 0.6020671834625323
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6466764583934904
# Test F1 Score LB= 0.3181818181818182
# Test Precision LB= 0.21939275220372184
# Test Recall LB= 0.5788113695090439
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6466764583934904
# Test F1 Score LB= 0.3181818181818182
# Test Precision LB= 0.21939275220372184
# Test Recall LB= 0.5788113695090439
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6466764583934904
# Test F1 Score LB= 0.3181818181818182
# Test Precision LB= 0.21939275220372184
# Test Recall LB= 0.5788113695090439
#
#
#  73.333 % Done
# Number of Estimators = 500 Depth = 7
#
# Train Balanced Accuracy XGB = 1.0
# Train F1 Score XGB = 1.0
# Train Precision XGB= 1.0
# Train Recall XGB= 1.0
#
# Test Balanced Score XGB = 0.6361748776496894
# Test F1 Score XGB = 0.3018625561978163
# Test Precision XGB= 0.20085470085470086
# Test Recall XGB= 0.6072351421188631
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.634883350732621
# Test F1 Score LB= 0.2968282465589467
# Test Precision LB= 0.19314641744548286
# Test Recall LB= 0.6408268733850129
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.634883350732621
# Test F1 Score LB= 0.2968282465589467
# Test Precision LB= 0.19314641744548286
# Test Recall LB= 0.6408268733850129
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.634883350732621
# Test F1 Score LB= 0.2968282465589467
# Test Precision LB= 0.19314641744548286
# Test Recall LB= 0.6408268733850129
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6382600156963787
# Test F1 Score LB= 0.30318471337579617
# Test Precision LB= 0.20118343195266272
# Test Recall LB= 0.6149870801033591
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6382600156963787
# Test F1 Score LB= 0.30318471337579617
# Test Precision LB= 0.20118343195266272
# Test Recall LB= 0.6149870801033591
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6382600156963787
# Test F1 Score LB= 0.30318471337579617
# Test Precision LB= 0.20118343195266272
# Test Recall LB= 0.6149870801033591
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6328486521104966
# Test F1 Score LB= 0.3019634394041977
# Test Precision LB= 0.20458715596330276
# Test Recall LB= 0.5762273901808785
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6328486521104966
# Test F1 Score LB= 0.3019634394041977
# Test Precision LB= 0.20458715596330276
# Test Recall LB= 0.5762273901808785
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6328486521104966
# Test F1 Score LB= 0.3019634394041977
# Test Precision LB= 0.20458715596330276
# Test Recall LB= 0.5762273901808785
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6346519772254429
# Test F1 Score LB= 0.3072505384063173
# Test Precision LB= 0.21272365805168986
# Test Recall LB= 0.5529715762273901
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6346519772254429
# Test F1 Score LB= 0.3072505384063173
# Test Precision LB= 0.21272365805168986
# Test Recall LB= 0.5529715762273901
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6346519772254429
# Test F1 Score LB= 0.3072505384063173
# Test Precision LB= 0.21272365805168986
# Test Recall LB= 0.5529715762273901
#
#
#  76.667 % Done
# Number of Estimators = 500 Depth = 10
#
# Train Balanced Accuracy XGB = 1.0
# Train F1 Score XGB = 1.0
# Train Precision XGB= 1.0
# Train Recall XGB= 1.0
#
# Test Balanced Score XGB = 0.6404344639168388
# Test F1 Score XGB = 0.30688524590163935
# Test Precision XGB= 0.2056239015817223
# Test Recall XGB= 0.6046511627906976
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6473298571777615
# Test F1 Score LB= 0.30741410488245935
# Test Precision LB= 0.20047169811320756
# Test Recall LB= 0.6589147286821705
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6473298571777615
# Test F1 Score LB= 0.30741410488245935
# Test Precision LB= 0.20047169811320756
# Test Recall LB= 0.6589147286821705
#
# Threshold for LightBoost = 0.45
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6473298571777615
# Test F1 Score LB= 0.30741410488245935
# Test Precision LB= 0.20047169811320756
# Test Recall LB= 0.6589147286821705
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.648954099198152
# Test F1 Score LB= 0.31218274111675126
# Test Precision LB= 0.20689655172413793
# Test Recall LB= 0.6356589147286822
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.648954099198152
# Test F1 Score LB= 0.31218274111675126
# Test Precision LB= 0.20689655172413793
# Test Recall LB= 0.6356589147286822
#
# Threshold for LightBoost = 0.5
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.648954099198152
# Test F1 Score LB= 0.31218274111675126
# Test Precision LB= 0.20689655172413793
# Test Recall LB= 0.6356589147286822
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
# Test Balanced Score LB= 0.6444765590872408
# Test F1 Score LB= 0.31224764468371463
# Test Precision LB= 0.2111010009099181
# Test Recall LB= 0.599483204134367
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6444765590872408
# Test F1 Score LB= 0.31224764468371463
# Test Precision LB= 0.2111010009099181
# Test Recall LB= 0.599483204134367
#
# Threshold for LightBoost = 0.55
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6444765590872408
# Test F1 Score LB= 0.31224764468371463
# Test Precision LB= 0.2111010009099181
# Test Recall LB= 0.599483204134367
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6410096584556837
# Test F1 Score LB= 0.31236749116607776
# Test Precision LB= 0.21498054474708173
# Test Recall LB= 0.5710594315245479
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6410096584556837
# Test F1 Score LB= 0.31236749116607776
# Test Precision LB= 0.21498054474708173
# Test Recall LB= 0.5710594315245479
#
# Threshold for LightBoost = 0.6
# Train Balanced Score LB = 1.0
# Train F1 Score LB = 1.0
# Train Precision LB= 1.0
# Train Recall LB= 1.0
#
# Test Balanced Score LB= 0.6410096584556837
# Test F1 Score LB= 0.31236749116607776
# Test Precision LB= 0.21498054474708173
# Test Recall LB= 0.5710594315245479

# %% [markdown]
# ### Cluster 2

# %%
results2 = model_selection(train_data2, X_test2, y_test2)
results2.to_csv('Results2.csv')
